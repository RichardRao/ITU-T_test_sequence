# %%
import numpy as np
import soundfile as sf
import binarizer as bz
import matplotlib.pyplot as plt
import pandas as pd
import vad
import os

# ITU-T supplement-23
OUT_META_DIR = '/home/richard/workspace/test_voice_generation/metadata/'
playlist = pd.DataFrame({}, columns=["file_id", "data_path"])
FS = 16000
FRAME_DUR = 0.002
NOISE_THR = -50
LEAD_SIL = 1 * FS
SMOOTHE_STEP = 1
STABILITY = 0.5 # Numnber of seconds for speech hang over time
SEGMENT_LENGTH_5 = 5 * FS
SEGMENT_LENGTH_10 = 10 * FS
NBITS = 16
NBITS_MAX = 2**(NBITS-1)
DATA_SET = 'Supp-23'
FILE_EXT = '.SRC'
DATA_DIR = '/home/richard/sambashare/media/ITU-T_test/P_Suppl_23_DB/'
total_time = 0
for dir_path, dir_name, file_names in os.walk(DATA_DIR, topdown=True):
    if len(file_names) == 0:
        continue
    if file_names[0].endswith(FILE_EXT):
        print(dir_path, dir_name, file_names)
    for idx, file_name in enumerate(file_names):
        if FILE_EXT not in file_name:
            continue
        data_path = os.path.join(dir_path,file_name)
        parent_dir = dir_path.split('/')[-1]
        data = np.memmap(data_path, dtype='<i2', mode='r')
        signal = np.array(data, copy=True).astype(float) / NBITS_MAX

        vadInst = vad.vad(signal, FS, FRAME_DUR, NBITS, NOISE_THR, SMOOTHE_STEP)
        binFlag, segments = bz.binarizer(vadInst.get_active_mask(level="sample"),STABILITY, FS)
        for sdx in range(len(segments["starts"])):
            segmented_signal = signal[segments["starts"][sdx]:segments["stops"][sdx]]
            segment_length = len(segmented_signal)
            # Sanity check
            if segments["stops"][sdx] <= segments["starts"][sdx]:
                continue
            file_id = file_name.replace(FILE_EXT, '') + '_' + str(sdx)
            output_path = os.path.join(dir_path, file_id + '.wav')
            if LEAD_SIL + segment_length < SEGMENT_LENGTH_5:
                output_signal = np.concatenate([np.zeros(LEAD_SIL).flatten(), segmented_signal, np.zeros(SEGMENT_LENGTH_5 - LEAD_SIL - segment_length).flatten()])
            elif LEAD_SIL + segment_length < SEGMENT_LENGTH_10:
                output_signal = np.concatenate([np.zeros(LEAD_SIL).flatten(), segmented_signal, np.zeros(SEGMENT_LENGTH_10 - LEAD_SIL - segment_length).flatten()])
            else:
                # raise error here
                raise Exception("Sorry segement length exceed limit")
            sf.write(output_path, output_signal, FS, 'PCM_16')
            playlist = pd.concat([\
                playlist, \
                pd.DataFrame([{\
                    "file_id": file_id, \
                    "src_data_path": data_path, \
                    "data_path": output_path, \
                    "data_set": DATA_SET, \
                    "parent_dir": parent_dir, \
                    "start": LEAD_SIL, \
                    "stop": LEAD_SIL + len(segmented_signal), \
                    }]) \
                ], ignore_index=True)
            total_time += len(segmented_signal) / FS
playlist.to_csv(os.path.join(OUT_META_DIR, 'ITU_playlist.csv'), index=False)
print("Total time: {:2.2f}".format(total_time))
# Out:
# /home/richard/sambashare/media/ITU-T_test/P_Suppl_23_DB/Disk1/EXP1/ORIGINAL/D [] ['._D_M02S10.SRC', '._D_F02S34.SRC', '._D_F01S44.SRC', 'D_M02S41_2.wav', '._D_M02S20.SRC', '._D_F01S41.SRC', 'D_F02S44_0.wav', 'D_F01S02_1.wav', 'D_M01S36.SRC', 'D_M01S31_1.wav', 'D_M02S42_1.wav', 'D_F01S20_1.wav', '._D_M02S13.SRC', 'D_M01S45.SRC', 'D_F01S37_2.wav', 'D_F01S38_0.wav', 'D_M02S12_1.wav', 'D_F02S04.SRC', '._D_M01S11.SRC', '._D_M02S24.SRC', 'D_M01S09_1.wav', 'D_F01S41_1.wav', 'D_F01S10_0.wav', 'D_M01S02_0.wav', 'D_F01S18_1.wav', 'D_F01S45_0.wav', 'D_M01S42_0.wav', 'D_F01S37_0.wav', 'D_M02S20_2.wav', 'D_F01S14.SRC', 'D_F02S33_0.wav', '._D_M02S34.SRC', 'D_F02S28_0.wav', '._D_M02S43.SRC', 'D_F02S19.SRC', 'D_F01S06_1.wav', '._D_M02S09.SRC', 'D_M02S16_0.wav', 'D_F02S20_0.wav', 'D_M02S45.SRC', 'D_M02S34_1.wav', 'D_F02S40.SRC', 'D_M01S07.SRC', 'D_F02S31.SRC', 'D_F01S04_1.wav', 'D_F02S37_1.wav', 'D_M02S11.SRC', 'D_M01S39_1.wav', 'D_M02S23.SRC', 'D_F02S25_0.wav', 'D_M01S14_0.wav', '._D_M02S30.SRC', '._D_M01S16.SRC', 'D_M01S11_1.wav', '._D_F01S42.SRC', 'D_F02S04_1.wav', 'D_M02S35_1.wav', 'D_M01S32_1.wav', '._D_M02S08.SRC', 'D_M01S15_0.wav', 'D_F02S19_0.wav', 'D_M01S15_1.wav', '._D_M01S04.SRC', 'D_F02S07_0.wav', 'D_M01S31.SRC', 'D_M01S10_1.wav', 'D_F01S08.SRC', 'D_M02S41.SRC', 'D_M02S21_1.wav', 'D_F02S32.SRC', 'D_M02S11_0.wav', 'D_M01S22.SRC', 'D_M02S23_2.wav', '._D_F01S09.SRC', 'D_F02S09_1.wav', 'D_M01S36_1.wav', 'D_M02S27.SRC', 'D_F01S39_1.wav', 'D_F02S11_0.wav', 'D_M01S08_1.wav', 'D_M02S08.SRC', 'D_F01S19.SRC', 'D_F02S25_1.wav', '._D_F02S06.SRC', 'D_F01S19_1.wav', 'D_F02S44.SRC', 'D_F02S26_1.wav', 'D_M02S13_1.wav', '._D_F01S26.SRC', 'D_F02S01_0.wav', 'D_F02S29.SRC', 'D_F02S25.SRC', 'D_F02S45_0.wav', 'D_M01S33_0.wav', '._D_F02S41.SRC', 'D_M02S36_1.wav', 'D_M02S42_0.wav', 'D_M01S25_1.wav', 'D_M01S35.SRC', '._D_M01S43.SRC', 'D_F02S40_1.wav', 'D_M02S35.SRC', 'D_F01S33_1.wav', 'D_F01S10.SRC', 'D_F02S47_0.wav', 'D_F01S27.SRC', 'D_F02S14_1.wav', 'D_F01S28_1.wav', 'D_F02S02.SRC', 'D_M02S29_1.wav', 'D_M02S47_0.wav', 'D_M02S28_0.wav', 'D_F02S03_0.wav', 'D_M01S33_1.wav', 'D_F01S16_0.wav', '._D_M02S23.SRC', 'D_M01S20_1.wav', 'D_M02S03_1.wav', '._D_M02S39.SRC', '._D_M01S37.SRC', 'D_M02S26_1.wav', '._D_F02S35.SRC', 'D_F01S15_1.wav', '._D_M02S41.SRC', '._D_F02S10.SRC', '._D_M02S02.SRC', 'D_F01S38_1.wav', 'D_F01S39.SRC', 'D_F01S26_0.wav', 'D_F01S22_1.wav', '._D_F01S08.SRC', '._D_F01S02.SRC', '._D_F01S35.SRC', 'D_F02S41_1.wav', '._D_F02S01.SRC', 'D_M01S12_1.wav', 'D_F02S12_1.wav', '._D_M01S47.SRC', 'D_M02S39_1.wav', 'D_F01S16_1.wav', 'D_M01S43.SRC', 'D_M01S09.SRC', 'D_F02S36_0.wav', 'D_F01S24_0.wav', 'D_M01S05.SRC', 'D_F01S33.SRC', 'D_F01S43_0.wav', '._D_F01S10.SRC', '._D_F02S22.SRC', 'D_M02S09_2.wav', 'D_F02S24.SRC', '._D_F02S39.SRC', 'D_F02S38_0.wav', 'D_M01S14.SRC', '._D_F01S13.SRC', 'D_M01S44_0.wav', 'D_M01S16_0.wav', 'D_M02S27_1.wav', 'D_F02S43.SRC', 'D_F01S29_0.wav', 'D_M01S16_1.wav', 'D_M02S31.SRC', 'D_M02S37.SRC', 'D_M01S17.SRC', 'D_F02S21_1.wav', 'D_F02S05_0.wav', 'D_M02S32.SRC', '._D_F01S12.SRC', 'D_M01S07_1.wav', 'D_M01S21_1.wav', 'D_M02S07.SRC', 'D_M01S38_1.wav', 'D_F01S01.SRC', '._D_F02S18.SRC', 'D_F01S13_0.wav', 'D_F01S05_0.wav', 'D_M02S31_1.wav', '._D_F01S05.SRC', '._D_M02S14.SRC', 'D_M02S31_0.wav', 'D_M01S18_1.wav', 'D_F01S31.SRC', 'D_M01S13.SRC', 'D_F02S29_1.wav', 'D_M02S39.SRC', 'D_F02S30.SRC', 'D_F01S06.SRC', '._D_M01S14.SRC', 'D_M01S43_1.wav', 'D_M01S19.SRC', 'D_F02S34.SRC', 'D_F01S43.SRC', 'D_M02S04_1.wav', 'D_M02S41_1.wav', '._D_M02S37.SRC', 'D_F01S29_1.wav', 'D_M02S24_1.wav', 'D_M01S02.SRC', 'D_F01S17.SRC', 'D_F02S23_0.wav', 'D_M01S24_0.wav', 'D_M01S38_0.wav', 'D_M02S30_0.wav', '._D_F02S32.SRC', '._D_M01S24.SRC', 'D_F02S35.SRC', 'D_M01S23_2.wav', 'D_F02S13_1.wav', 'D_M02S18.SRC', '._D_F01S36.SRC', 'D_F01S06_2.wav', '._D_F01S32.SRC', '._D_M01S28.SRC', 'D_F01S05_1.wav', 'D_F01S21_0.wav', 'D_M01S09_0.wav', 'D_M02S33.SRC', 'D_M01S29_1.wav', 'D_M02S13_0.wav', 'D_F02S21.SRC', 'D_F01S23_1.wav', 'D_M02S23_1.wav', '._D_F01S20.SRC', '._D_F01S46.SR ...
# /home/richard/sambashare/media/ITU-T_test/P_Suppl_23_DB/Disk1/EXP1/ORIGINAL/A [] ['._A_F01S17.SRC', 'A_F01S32_1.wav', '._A_F01S13.SRC', 'A_F02S38_0.wav', 'A_M01S26_1.wav', 'A_F01S34_1.wav', 'A_M02S41_1.wav', 'A_F02S38.SRC', 'A_F02S19_1.wav', '._A_M01S25.SRC', '._A_M01S08.SRC', 'A_M01S17.SRC', 'A_F02S15_1.wav', 'A_F02S34_1.wav', 'A_F02S32_0.wav', '._A_M01S24.SRC', 'A_M02S46_1.wav', 'A_F02S09_0.wav', 'A_F02S31.SRC', '._A_F01S45.SRC', 'A_M02S33_0.wav', 'A_F02S22.SRC', 'A_M02S15_1.wav', '._A_M02S08.SRC', 'A_M01S44_1.wav', 'A_M02S33.SRC', 'A_M02S23.SRC', 'A_M02S16_0.wav', 'A_M02S36_1.wav', 'A_M01S10_0.wav', 'A_M01S17_1.wav', 'A_M02S05_0.wav', '._A_M01S23.SRC', 'A_F01S15.SRC', 'A_F01S44_0.wav', 'A_F02S42_0.wav', 'A_M02S20.SRC', '._A_F02S39.SRC', 'A_M01S19.SRC', 'A_M02S04_0.wav', 'A_M02S09_0.wav', 'A_M02S21.SRC', 'A_M02S34_0.wav', 'A_F02S11_1.wav', 'A_M02S26_0.wav', 'A_F02S26_1.wav', '._A_F02S12.SRC', 'A_M02S35.SRC', 'A_F02S07_1.wav', 'A_F02S05.SRC', 'A_F02S02_0.wav', 'A_F02S04_0.wav', 'A_F01S12.SRC', 'A_F01S22.SRC', '._A_F02S01.SRC', 'A_M01S11_0.wav', 'A_M01S09.SRC', 'A_F01S35.SRC', 'A_M02S33_1.wav', 'A_F01S19_0.wav', 'A_F02S21.SRC', 'A_F01S33_1.wav', 'A_M02S47_1.wav', '._A_F02S38.SRC', 'A_F01S21_0.wav', 'A_F01S46_0.wav', '._A_F01S18.SRC', '._A_M02S04.SRC', 'A_F02S04.SRC', 'A_M02S13_0.wav', 'A_M01S45_1.wav', '._A_M01S06.SRC', 'A_F01S45.SRC', 'A_M02S11.SRC', 'A_M02S18_0.wav', 'A_F02S45_0.wav', '._A_F02S13.SRC', 'A_M02S21_0.wav', 'A_M01S19_1.wav', 'A_M01S14.SRC', 'A_M01S36_1.wav', 'A_M01S05_1.wav', 'A_M02S25.SRC', 'A_F01S07_1.wav', 'A_F01S39.SRC', 'A_M02S23_0.wav', 'A_F01S38.SRC', '._A_M02S27.SRC', 'A_F02S25_1.wav', 'A_M02S04.SRC', 'A_M02S42_0.wav', '._A_M02S15.SRC', 'A_F01S28.SRC', 'A_M02S18_1.wav', 'A_M01S26_0.wav', 'A_F01S41_0.wav', '._A_F01S44.SRC', 'A_F01S33.SRC', 'A_M01S16_1.wav', 'A_F01S25_1.wav', 'A_M01S01_0.wav', 'A_F01S32_0.wav', 'A_M01S06_1.wav', '._A_F02S44.SRC', 'A_M02S15_0.wav', 'A_M02S29_1.wav', 'A_F02S46_0.wav', 'A_M02S06.SRC', 'A_M01S19_0.wav', '._A_M02S43.SRC', 'A_F02S08.SRC', 'A_F02S30.SRC', 'A_M01S13_0.wav', 'A_M02S31_0.wav', '._A_F02S33.SRC', 'A_M01S09_0.wav', 'A_F02S03_1.wav', 'A_F01S35_1.wav', 'A_F02S30_1.wav', 'A_F01S16_1.wav', 'A_M02S12_1.wav', 'A_M02S13.SRC', 'A_F02S01_1.wav', 'A_F01S15_1.wav', 'A_F02S23_0.wav', 'A_F01S40.SRC', 'A_M01S34_1.wav', 'A_M01S24.SRC', 'A_F02S44_1.wav', 'A_M02S25_0.wav', 'A_F01S30_1.wav', 'A_M01S16_0.wav', 'A_M02S12_0.wav', 'A_F01S23_0.wav', '._A_F01S41.SRC', 'A_F01S47.SRC', '._A_M01S27.SRC', 'A_F02S40_0.wav', '._A_F01S37.SRC', '._A_M01S19.SRC', 'A_F02S22_1.wav', '._A_M01S03.SRC', 'A_M01S33.SRC', 'A_F02S15.SRC', 'A_M01S29.SRC', 'A_F01S21_1.wav', 'A_F01S42.SRC', 'A_F01S43_1.wav', 'A_M02S07_1.wav', 'A_M02S29.SRC', '._A_M02S41.SRC', 'A_M02S46.SRC', 'A_M02S43.SRC', 'A_F01S01_0.wav', 'A_F02S16_1.wav', '._A_F02S18.SRC', 'A_M02S21_1.wav', 'A_M02S35_1.wav', '._A_M02S34.SRC', 'A_M01S24_1.wav', 'A_F02S12_0.wav', 'A_M02S16.SRC', 'A_M02S14_1.wav', 'A_M01S37_0.wav', '._A_F02S08.SRC', 'A_F02S15_0.wav', 'A_M02S29_0.wav', 'A_M01S23.SRC', 'A_M01S37_1.wav', 'A_F02S32_1.wav', 'A_M02S02_0.wav', 'A_F01S02.SRC', 'A_M01S03_1.wav', 'A_F02S08_1.wav', '._A_F02S40.SRC', '._A_F02S45.SRC', 'A_F01S11_1.wav', '._A_F01S22.SRC', 'A_F02S05_0.wav', '._A_F01S27.SRC', '._A_F01S47.SRC', 'A_M01S18_1.wav', 'A_M02S07_0.wav', '._A_F02S34.SRC', 'A_M01S38_1.wav', 'A_F02S18_0.wav', '._A_M01S41.SRC', '._A_M01S29.SRC', '._A_M02S14.SRC', 'A_M01S31_1.wav', 'A_M02S45.SRC', 'A_F01S40_0.wav', 'A_F02S13.SRC', '._A_M01S04.SRC', 'A_F01S04.SRC', 'A_M02S37.SRC', 'A_F02S45_1.wav', 'A_M02S46_0.wav', 'A_F01S44.SRC', 'A_F01S33_0.wav', 'A_M01S25_1.wav', 'A_F01S08_1.wav', 'A_M01S20_1.wav', 'A_F01S42_0.wav', 'A_F01S24_0.wav', '._A_F01S26.SRC', '._A_F02S09.SRC', 'A_M01S23_1.wav', 'A_F01S29.SRC', 'A_M01S03.SRC', 'A_F01S41_1.wav', 'A_F01S27_0.wav', '._A_F02S46.SRC', '._A_M02S40.SRC', '._A_F02S15.SRC', 'A_M01S33_0.wav', 'A_M01S30_0.wav', 'A_F02S39.SRC', 'A_F01S19_1.wav', 'A_F01S10_1.wav', 'A_M01S42_0.wav', 'A_M01S13.SRC', '._A_M01S13.SRC', 'A_M02S06_ ...
# /home/richard/sambashare/media/ITU-T_test/P_Suppl_23_DB/Disk1/EXP1/ORIGINAL/O [] ['O_F01S40.SRC', 'O_M02S29_0.wav', 'O_M01S47_1.wav', 'O_M02S26.SRC', '._O_F01S22.SRC', '._O_F01S37.SRC', '._O_F01S44.SRC', '._O_F01S03.SRC', 'O_F01S15_0.wav', '._O_F02S29.SRC', 'O_F01S18_1.wav', '._O_M01S19.SRC', '._O_F01S29.SRC', '._O_M02S47.SRC', '._O_M01S23.SRC', 'O_M01S33.SRC', '._O_F02S04.SRC', 'O_F02S08.SRC', 'O_F02S41_1.wav', 'O_M02S14_0.wav', '._O_F01S26.SRC', '._O_F01S04.SRC', '._O_F02S22.SRC', '._O_F02S42.SRC', 'O_F02S34_0.wav', 'O_M02S22_1.wav', 'O_F01S07_0.wav', 'O_F02S05_1.wav', 'O_M02S22.SRC', 'O_F02S31_0.wav', 'O_M02S32_0.wav', 'O_M02S06_1.wav', 'O_M02S18_1.wav', 'O_F02S03_1.wav', 'O_M02S17_0.wav', 'O_F01S28_0.wav', 'O_M01S08.SRC', 'O_M02S25_1.wav', 'O_M01S43_0.wav', 'O_F01S02.SRC', 'O_F02S46_0.wav', 'O_F02S28_0.wav', 'O_F01S10.SRC', '._O_F01S24.SRC', 'O_M02S39_0.wav', '._O_F02S14.SRC', 'O_M02S23.SRC', '._O_F01S35.SRC', 'O_M01S42_1.wav', 'O_F02S29.SRC', 'O_F01S06_0.wav', 'O_F01S23_1.wav', 'O_F01S39.SRC', 'O_M01S22_0.wav', 'O_F01S03_1.wav', 'O_F01S08.SRC', 'O_F01S35.SRC', 'O_F02S08_1.wav', 'O_F01S41_0.wav', '._O_M01S45.SRC', 'O_M01S07_0.wav', 'O_M02S44_1.wav', '._O_M02S09.SRC', 'O_F01S09_0.wav', 'O_F02S04.SRC', '._O_M01S38.SRC', '._O_F02S09.SRC', 'O_M01S12.SRC', 'O_M02S36_1.wav', 'O_F01S25_1.wav', 'O_M02S29_1.wav', 'O_F02S10.SRC', 'O_F01S22_0.wav', 'O_F02S35_1.wav', 'O_F02S44_1.wav', 'O_F01S30_0.wav', '._O_M02S33.SRC', '._O_M02S20.SRC', 'O_F01S40_1.wav', 'O_M01S43_1.wav', 'O_M02S31_0.wav', 'O_F02S38.SRC', '._O_F01S36.SRC', 'O_M02S38.SRC', '._O_F01S08.SRC', 'O_F02S31.SRC', 'O_M01S02_0.wav', 'O_F02S09_1.wav', 'O_M01S34_1.wav', 'O_M02S11_1.wav', 'O_M02S47_1.wav', 'O_M02S23_0.wav', '._O_M02S06.SRC', 'O_F01S27.SRC', 'O_F01S02_0.wav', 'O_F01S28_1.wav', 'O_M02S35_1.wav', 'O_M01S26_0.wav', 'O_F02S25_1.wav', 'O_F02S05_0.wav', 'O_F01S14_1.wav', 'O_M02S20.SRC', '._O_M02S19.SRC', '._O_F02S31.SRC', 'O_M02S38_1.wav', '._O_F02S05.SRC', '._O_M01S33.SRC', 'O_F01S21.SRC', 'O_M01S46.SRC', '._O_M01S13.SRC', '._O_M01S02.SRC', 'O_M02S15.SRC', 'O_F02S30_0.wav', 'O_F02S37_1.wav', '._O_M02S05.SRC', 'O_M01S04_0.wav', '._O_M01S41.SRC', 'O_F02S13.SRC', 'O_M02S10_1.wav', '._O_F01S16.SRC', 'O_F01S44_1.wav', 'O_M01S34.SRC', '._O_F01S10.SRC', 'O_F02S36_0.wav', 'O_F02S21_0.wav', 'O_M01S01.SRC', '._O_M02S42.SRC', 'O_F01S22.SRC', 'O_F01S17_0.wav', 'O_F01S05.SRC', '._O_M02S04.SRC', 'O_M02S27_0.wav', 'O_F02S11_1.wav', 'O_M01S14_1.wav', 'O_F01S43.SRC', 'O_M01S37_0.wav', '._O_F02S43.SRC', 'O_M02S21_1.wav', 'O_F02S33_1.wav', 'O_M01S03.SRC', 'O_F02S21_1.wav', 'O_F01S05_1.wav', 'O_M02S44_0.wav', '._O_M01S46.SRC', 'O_F02S25_0.wav', 'O_F02S46_1.wav', 'O_M02S12_1.wav', 'O_M02S29.SRC', 'O_F02S28.SRC', 'O_F02S16_0.wav', 'O_M02S44.SRC', '._O_F02S36.SRC', 'O_M02S20_0.wav', 'O_F01S27_0.wav', 'O_F01S17.SRC', 'O_M01S32.SRC', 'O_M01S03_0.wav', 'O_M02S28_1.wav', 'O_M02S16_0.wav', 'O_M01S17.SRC', 'O_M01S44_1.wav', 'O_F01S12_0.wav', '._O_F01S14.SRC', 'O_M02S46.SRC', 'O_M02S43_1.wav', '._O_F01S39.SRC', 'O_M02S45_1.wav', 'O_F02S01_0.wav', 'O_M02S19_1.wav', '._O_M02S32.SRC', 'O_M01S46_1.wav', 'O_F02S17.SRC', 'O_M02S08_1.wav', '._O_M01S21.SRC', 'O_M01S11_1.wav', '._O_F01S23.SRC', 'O_F01S42_0.wav', 'O_M02S22_0.wav', '._O_F02S21.SRC', 'O_M01S29.SRC', '._O_F01S31.SRC', 'O_F02S45.SRC', 'O_F02S02_0.wav', 'O_F01S18_0.wav', '._O_M02S31.SRC', 'O_F01S11_1.wav', 'O_F02S07_1.wav', 'O_F01S01_1.wav', 'O_M01S40_1.wav', 'O_M01S21_1.wav', 'O_M01S35_1.wav', 'O_M02S12.SRC', 'O_F02S26_0.wav', '._O_F02S39.SRC', 'O_M02S16_1.wav', '._O_F01S38.SRC', '._O_F01S43.SRC', 'O_F02S01_1.wav', 'O_F01S08_0.wav', 'O_M02S42.SRC', 'O_M02S03_1.wav', 'O_F01S44.SRC', 'O_M01S31.SRC', '._O_F01S25.SRC', 'O_M01S19_0.wav', 'O_M01S10_0.wav', 'O_F01S42.SRC', '._O_F01S42.SRC', '._O_M01S08.SRC', '._O_F01S45.SRC', 'O_M01S01_1.wav', 'O_F01S07.SRC', 'O_M02S06.SRC', 'O_F01S42_1.wav', 'O_F01S14.SRC', 'O_M01S20_1.wav', '._O_F01S20.SRC', 'O_F01S31.SRC', 'O_F01S04_0.wav', 'O_F02S26.SRC', '._O_F01S41.SRC', 'O_F02S42_0.wav', 'O_M02S31_1.wav', 'O_M02 ...
# /home/richard/sambashare/media/ITU-T_test/P_Suppl_23_DB/Disk3/EXP3/ORIGINAL/D [] ['._D_M02S10.SRC', '._D_F02S34.SRC', '._D_F01S44.SRC', '._D_M02S20.SRC', '._D_F01S41.SRC', 'D_F02S52_1.wav', 'D_F02S44_0.wav', 'D_F01S02_1.wav', 'D_M01S36.SRC', 'D_M01S31_1.wav', 'D_M02S18_2.wav', 'D_M02S42_1.wav', 'D_F01S20_1.wav', '._D_M02S13.SRC', 'D_M01S45.SRC', 'D_F01S38_0.wav', 'D_M02S12_1.wav', 'D_F02S04.SRC', '._D_M01S11.SRC', '._D_M02S24.SRC', 'D_M01S09_1.wav', 'D_F01S41_1.wav', 'D_F01S10_0.wav', 'D_M01S02_0.wav', 'D_F01S18_1.wav', 'D_F01S45_0.wav', 'D_M01S42_0.wav', 'D_F01S37_0.wav', '._D_F02S49.SRC', 'D_F01S14.SRC', 'D_F02S33_0.wav', 'D_M02S07_2.wav', '._D_M02S34.SRC', 'D_F02S28_0.wav', '._D_M02S43.SRC', 'D_F01S48.SRC', 'D_M02S50_0.wav', 'D_F02S19.SRC', 'D_F01S06_1.wav', '._D_M02S09.SRC', 'D_M02S16_0.wav', 'D_F02S20_0.wav', 'D_M02S24_2.wav', 'D_M02S45.SRC', 'D_M02S34_1.wav', 'D_M02S31_2.wav', 'D_F02S40.SRC', 'D_M01S07.SRC', 'D_F02S31.SRC', 'D_F01S04_1.wav', 'D_F02S37_1.wav', 'D_M02S11.SRC', 'D_M01S39_1.wav', 'D_M02S23.SRC', 'D_F02S25_0.wav', 'D_M01S14_0.wav', '._D_M02S30.SRC', 'D_F01S51_0.wav', '._D_M01S16.SRC', 'D_M01S11_1.wav', '._D_F01S42.SRC', 'D_F02S04_1.wav', 'D_M02S35_1.wav', 'D_M01S32_1.wav', '._D_M02S08.SRC', 'D_M01S15_0.wav', 'D_F02S19_0.wav', 'D_M01S15_1.wav', '._D_M01S04.SRC', 'D_F02S07_0.wav', 'D_M01S31.SRC', 'D_M01S10_1.wav', 'D_F01S08.SRC', 'D_M02S41.SRC', 'D_M02S21_1.wav', 'D_F02S32.SRC', 'D_M02S11_0.wav', 'D_M01S22.SRC', '._D_F01S09.SRC', 'D_F02S09_1.wav', 'D_M01S36_1.wav', 'D_M02S27.SRC', 'D_F01S39_1.wav', 'D_F02S11_0.wav', 'D_M01S08_1.wav', 'D_M02S08.SRC', 'D_F01S19.SRC', 'D_F02S25_1.wav', '._D_F02S06.SRC', 'D_F01S19_1.wav', 'D_F02S44.SRC', 'D_F02S26_1.wav', 'D_M01S39_2.wav', 'D_M02S13_1.wav', '._D_F01S26.SRC', 'D_F02S01_0.wav', 'D_F01S50.SRC', 'D_F02S29.SRC', 'D_F02S25.SRC', 'D_F02S45_0.wav', 'D_F02S49_1.wav', 'D_M01S33_0.wav', '._D_F02S41.SRC', 'D_F01S49.SRC', 'D_M02S36_1.wav', 'D_M02S42_0.wav', 'D_M01S25_1.wav', 'D_M01S35.SRC', '._D_M01S43.SRC', 'D_F02S40_1.wav', 'D_M02S35.SRC', 'D_F01S33_1.wav', 'D_F01S10.SRC', 'D_F02S47_0.wav', 'D_F01S27.SRC', 'D_F02S14_1.wav', 'D_F01S28_1.wav', 'D_F02S02.SRC', '._D_F01S48.SRC', 'D_M02S29_1.wav', 'D_M02S47_0.wav', 'D_M02S28_0.wav', 'D_F02S03_0.wav', 'D_M01S33_1.wav', 'D_F01S16_0.wav', 'D_M02S50.SRC', '._D_F01S49.SRC', 'D_M01S48_1.wav', '._D_M02S52.SRC', '._D_M02S23.SRC', 'D_M01S20_1.wav', 'D_M02S03_1.wav', '._D_M02S39.SRC', '._D_M01S37.SRC', 'D_M02S26_1.wav', '._D_F02S35.SRC', 'D_F01S15_1.wav', '._D_M02S41.SRC', '._D_F02S10.SRC', '._D_M02S02.SRC', 'D_F01S38_1.wav', 'D_F01S39.SRC', 'D_F01S26_0.wav', 'D_F01S22_1.wav', '._D_F01S08.SRC', '._D_F01S02.SRC', '._D_F01S35.SRC', 'D_F02S41_1.wav', '._D_F02S01.SRC', 'D_M01S12_1.wav', 'D_F02S12_1.wav', '._D_M01S47.SRC', 'D_M02S39_1.wav', 'D_F01S16_1.wav', 'D_M01S43.SRC', 'D_M01S09.SRC', 'D_F02S36_0.wav', 'D_F01S49_1.wav', 'D_F01S24_0.wav', 'D_M01S05.SRC', 'D_F01S49_0.wav', 'D_F01S33.SRC', 'D_F01S43_0.wav', '._D_F01S10.SRC', '._D_F02S22.SRC', 'D_F02S24.SRC', '._D_F02S39.SRC', 'D_F02S38_0.wav', 'D_F01S11_2.wav', 'D_M01S14.SRC', '._D_F01S13.SRC', 'D_M01S44_0.wav', 'D_M01S16_0.wav', 'D_M02S27_1.wav', 'D_M02S10_1.wav', 'D_F02S43.SRC', 'D_F01S29_0.wav', 'D_M02S16_2.wav', 'D_M01S16_1.wav', 'D_M02S31.SRC', 'D_M02S37.SRC', 'D_F01S48_0.wav', 'D_M01S17.SRC', 'D_F02S21_1.wav', 'D_F02S05_0.wav', 'D_M02S32.SRC', '._D_F01S12.SRC', 'D_M01S07_1.wav', 'D_F02S52_0.wav', 'D_M01S21_1.wav', 'D_M02S07.SRC', 'D_F01S01_2.wav', 'D_M01S38_1.wav', 'D_F01S01.SRC', '._D_F02S18.SRC', 'D_F01S13_0.wav', 'D_F01S05_0.wav', 'D_M02S31_1.wav', '._D_F01S05.SRC', 'D_M02S43_3.wav', '._D_M02S14.SRC', 'D_M02S31_0.wav', 'D_F01S52_0.wav', 'D_M01S18_1.wav', 'D_F01S31.SRC', 'D_M01S13.SRC', 'D_F02S29_1.wav', 'D_M02S39.SRC', 'D_F02S30.SRC', 'D_F02S50_1.wav', 'D_M01S51_1.wav', 'D_F01S06.SRC', '._D_M01S14.SRC', 'D_M01S43_1.wav', 'D_M02S52_0.wav', 'D_M01S48.SRC', 'D_M01S19.SRC', 'D_F02S34.SRC', 'D_F01S43.SRC', 'D_M02S04_1.wav', 'D_M02S41_1.wav', '._D_M02S37.SRC', 'D_F01S29_1.wav', 'D_M02S48_0. ...
# /home/richard/sambashare/media/ITU-T_test/P_Suppl_23_DB/Disk3/EXP3/ORIGINAL/C [] ['C_M01S10.SRC', 'C_F02S14.SRC', 'C_F02S33.SRC', 'C_F01S19.SRC', 'C_M01S42.SRC', '._C_F01S32.SRC', 'C_M01S13_1.wav', '._C_F01S47.SRC', 'C_M02S25_0.wav', 'C_F01S33_1.wav', 'C_F01S48.SRC', 'C_M02S26.SRC', 'C_F01S47_0.wav', 'C_M01S32.SRC', 'C_F01S06_1.wav', 'C_M01S01_1.wav', '._C_F02S46.SRC', 'C_M02S18_1.wav', 'C_F01S16_0.wav', 'C_M02S05_0.wav', 'C_M02S52_1.wav', '._C_F02S12.SRC', 'C_F02S04.SRC', 'C_F01S45_1.wav', 'C_F01S37.SRC', 'C_F02S37_1.wav', 'C_F01S15_0.wav', '._C_F01S41.SRC', '._C_F01S25.SRC', '._C_M02S31.SRC', '._C_F01S49.SRC', 'C_M01S15.SRC', 'C_F01S39_1.wav', '._C_F01S24.SRC', '._C_F01S19.SRC', '._C_F02S42.SRC', 'C_F01S11_0.wav', 'C_F01S33.SRC', 'C_M02S42_0.wav', '._C_F01S18.SRC', 'C_M01S06_1.wav', 'C_M02S41_0.wav', 'C_M01S45_0.wav', 'C_M01S47.SRC', 'C_M01S04_0.wav', 'C_M02S46.SRC', 'C_F01S50.SRC', 'C_F02S09_1.wav', 'C_M02S28_0.wav', 'C_M02S50_0.wav', 'C_M01S52_0.wav', '._C_F02S17.SRC', '._C_M01S32.SRC', '._C_M02S36.SRC', 'C_M02S24_1.wav', 'C_F01S30_0.wav', 'C_F02S16_1.wav', 'C_M01S10_0.wav', '._C_F01S04.SRC', 'C_F01S08_1.wav', '._C_F02S03.SRC', 'C_F01S28.SRC', 'C_F01S46_1.wav', 'C_M02S10_0.wav', 'C_F02S09_0.wav', '._C_M01S25.SRC', 'C_F02S01_1.wav', 'C_F01S13.SRC', 'C_F02S45_1.wav', 'C_F01S02.SRC', '._C_F02S14.SRC', 'C_M02S23_0.wav', 'C_M01S16.SRC', '._C_M02S21.SRC', 'C_M02S20_1.wav', 'C_M01S26_0.wav', 'C_M02S36_0.wav', '._C_F02S32.SRC', 'C_F02S29_0.wav', '._C_F02S45.SRC', 'C_M01S19_1.wav', 'C_M02S52.SRC', 'C_F01S42_1.wav', '._C_M02S27.SRC', '._C_M01S37.SRC', '._C_F02S38.SRC', 'C_F02S12.SRC', 'C_F02S31_1.wav', 'C_F02S36_1.wav', 'C_M01S50.SRC', '._C_F01S01.SRC', 'C_F02S15_1.wav', '._C_F01S28.SRC', 'C_F02S46_1.wav', 'C_F02S04_1.wav', 'C_F01S49_0.wav', '._C_M01S09.SRC', '._C_F01S20.SRC', 'C_F02S13.SRC', 'C_M02S06_1.wav', '._C_F01S22.SRC', 'C_M02S28.SRC', 'C_M02S39_0.wav', 'C_M02S49_1.wav', 'C_F02S49_0.wav', 'C_M01S49_1.wav', 'C_M02S24_0.wav', '._C_F02S07.SRC', 'C_M02S12_1.wav', 'C_M01S25.SRC', '._C_F02S24.SRC', 'C_M01S27.SRC', '._C_M01S20.SRC', 'C_M02S20.SRC', '._C_M02S05.SRC', 'C_F01S43.SRC', 'C_F01S43_1.wav', 'C_M01S40_1.wav', 'C_F02S11.SRC', 'C_M02S25_1.wav', '._C_M02S46.SRC', 'C_F02S10_1.wav', 'C_M01S37_1.wav', 'C_F01S21_0.wav', '._C_M01S12.SRC', 'C_F01S34_0.wav', 'C_F02S32_1.wav', 'C_F02S43.SRC', 'C_F02S21.SRC', '._C_F02S44.SRC', '._C_F01S23.SRC', 'C_F02S16_0.wav', '._C_M01S01.SRC', 'C_M02S13_0.wav', 'C_F02S52_1.wav', '._C_F01S46.SRC', 'C_M01S40.SRC', 'C_F01S23.SRC', 'C_M01S01_2.wav', 'C_F01S26.SRC', 'C_F02S39_0.wav', 'C_M02S42.SRC', '._C_F02S08.SRC', 'C_F01S44_1.wav', 'C_M01S43_0.wav', '._C_F02S06.SRC', '._C_M01S47.SRC', 'C_F01S47_1.wav', '._C_M02S40.SRC', 'C_M01S44_1.wav', 'C_M01S47_1.wav', 'C_M01S24_0.wav', 'C_F01S29_1.wav', '._C_M01S27.SRC', '._C_F01S33.SRC', 'C_M01S12_0.wav', '._C_F01S14.SRC', 'C_M02S22.SRC', 'C_M02S23_1.wav', 'C_F02S30_1.wav', '._C_M01S17.SRC', 'C_M02S35.SRC', 'C_M02S21_1.wav', 'C_M02S43.SRC', '._C_M01S03.SRC', 'C_M02S36.SRC', '._C_M01S21.SRC', 'C_F01S42.SRC', 'C_M01S41_0.wav', '._C_M02S20.SRC', 'C_M02S48_0.wav', 'C_M01S03.SRC', '._C_F01S31.SRC', 'C_M02S38_0.wav', '._C_M02S28.SRC', 'C_M02S31_1.wav', '._C_M01S34.SRC', 'C_M02S51_0.wav', 'C_F02S26.SRC', 'C_F01S10_1.wav', 'C_F01S20_0.wav', 'C_M02S01_1.wav', '._C_M02S33.SRC', '._C_M01S45.SRC', 'C_M02S03_1.wav', 'C_F02S12_1.wav', 'C_F02S07_1.wav', 'C_F02S51.SRC', 'C_F01S24_1.wav', 'C_M01S12_1.wav', 'C_M02S32_0.wav', '._C_F01S37.SRC', 'C_F02S17_1.wav', 'C_F01S19_0.wav', 'C_M01S42_0.wav', 'C_F02S47_1.wav', 'C_F02S20_1.wav', 'C_M01S46_0.wav', '._C_M01S52.SRC', 'C_M01S45.SRC', '._C_M01S16.SRC', 'C_F02S38_1.wav', 'C_M02S41.SRC', '._C_M01S07.SRC', 'C_F02S04_0.wav', '._C_F02S28.SRC', 'C_F02S01_0.wav', 'C_M01S29_1.wav', '._C_M02S24.SRC', 'C_M02S49.SRC', 'C_M01S11_1.wav', 'C_F01S01_1.wav', 'C_F02S45_0.wav', '._C_M01S26.SRC', 'C_M02S08.SRC', '._C_M02S47.SRC', 'C_F02S26_1.wav', 'C_M01S38_0.wav', '._C_M01S15.SRC', 'C_M01S25_0.wav', 'C_M02S13_1.wav', 'C_M02S02_0.wav', '._C_M02S14.SRC' ...
# /home/richard/sambashare/media/ITU-T_test/P_Suppl_23_DB/Disk3/EXP3/ORIGINAL/A [] ['._A_F01S17.SRC', 'A_F01S32_1.wav', '._A_F01S13.SRC', 'A_M01S48_0.wav', 'A_F02S38_0.wav', 'A_M01S26_1.wav', 'A_F01S34_1.wav', 'A_M02S50.SRC', 'A_M02S41_1.wav', 'A_F02S38.SRC', 'A_F02S19_1.wav', '._A_M01S25.SRC', '._A_M01S08.SRC', 'A_M01S17.SRC', 'A_F02S15_1.wav', 'A_F02S34_1.wav', 'A_F02S32_0.wav', '._A_M01S24.SRC', '._A_F01S52.SRC', 'A_M02S46_1.wav', 'A_F02S09_0.wav', '._A_F02S51.SRC', 'A_F02S31.SRC', '._A_F01S45.SRC', 'A_M02S33_0.wav', 'A_F02S22.SRC', 'A_M02S15_1.wav', '._A_M02S08.SRC', 'A_M01S44_1.wav', 'A_M02S33.SRC', 'A_M02S23.SRC', 'A_M02S16_0.wav', 'A_M02S36_1.wav', 'A_M01S10_0.wav', 'A_M01S17_1.wav', 'A_M02S05_0.wav', '._A_M01S23.SRC', 'A_F01S15.SRC', 'A_F01S44_0.wav', 'A_F02S42_0.wav', 'A_M02S20.SRC', 'A_F02S52_1.wav', '._A_F02S39.SRC', 'A_M01S19.SRC', 'A_M02S04_0.wav', 'A_M02S09_0.wav', 'A_M02S21.SRC', 'A_M02S34_0.wav', 'A_F02S11_1.wav', 'A_M02S26_0.wav', 'A_F02S26_1.wav', 'A_M02S52.SRC', '._A_F02S12.SRC', 'A_M02S35.SRC', 'A_F01S51.SRC', 'A_F02S07_1.wav', 'A_F02S05.SRC', 'A_F02S02_0.wav', 'A_F02S04_0.wav', 'A_F01S12.SRC', 'A_F01S22.SRC', '._A_F02S01.SRC', 'A_M01S11_0.wav', 'A_M01S09.SRC', 'A_F01S35.SRC', 'A_M02S33_1.wav', 'A_F01S19_0.wav', 'A_F02S21.SRC', 'A_F01S33_1.wav', 'A_M02S47_1.wav', '._A_F02S38.SRC', 'A_F01S21_0.wav', 'A_F01S46_0.wav', 'A_F02S50_1.wav', '._A_F01S18.SRC', '._A_M02S04.SRC', 'A_F02S04.SRC', 'A_M02S13_0.wav', 'A_M01S45_1.wav', '._A_M01S06.SRC', 'A_F01S45.SRC', 'A_M02S11.SRC', 'A_M02S18_0.wav', 'A_F02S45_0.wav', '._A_F02S13.SRC', 'A_M02S21_0.wav', 'A_M01S19_1.wav', 'A_M01S14.SRC', 'A_M01S36_1.wav', 'A_M01S05_1.wav', 'A_M02S25.SRC', 'A_F01S07_1.wav', 'A_F01S39.SRC', 'A_M02S23_0.wav', 'A_F01S38.SRC', '._A_M02S27.SRC', 'A_M01S52.SRC', 'A_F02S25_1.wav', 'A_M02S04.SRC', 'A_M02S42_0.wav', 'A_M01S52_1.wav', '._A_M02S15.SRC', 'A_F01S28.SRC', 'A_M02S18_1.wav', 'A_M01S26_0.wav', 'A_F01S41_0.wav', '._A_F01S44.SRC', 'A_M02S48.SRC', 'A_F01S33.SRC', 'A_M01S16_1.wav', 'A_F01S25_1.wav', 'A_M01S01_0.wav', 'A_F01S32_0.wav', 'A_M01S06_1.wav', '._A_F02S44.SRC', 'A_M02S15_0.wav', 'A_M02S29_1.wav', 'A_F02S46_0.wav', 'A_F01S49_0.wav', 'A_M02S06.SRC', 'A_M01S19_0.wav', '._A_M02S43.SRC', 'A_F02S08.SRC', 'A_F02S30.SRC', 'A_M01S13_0.wav', 'A_F02S52.SRC', 'A_M02S31_0.wav', '._A_F02S33.SRC', 'A_M01S09_0.wav', 'A_F02S03_1.wav', 'A_F01S35_1.wav', 'A_F02S30_1.wav', 'A_F01S16_1.wav', 'A_M02S12_1.wav', 'A_M02S13.SRC', 'A_F02S01_1.wav', 'A_F01S15_1.wav', 'A_F02S23_0.wav', 'A_F01S40.SRC', 'A_M01S34_1.wav', 'A_M01S24.SRC', 'A_F02S44_1.wav', 'A_M02S25_0.wav', 'A_F01S30_1.wav', 'A_M01S16_0.wav', 'A_M02S12_0.wav', 'A_F01S23_0.wav', '._A_F01S41.SRC', 'A_M01S49.SRC', 'A_F01S47.SRC', '._A_M01S27.SRC', 'A_F02S40_0.wav', '._A_F01S37.SRC', '._A_M01S19.SRC', 'A_F02S22_1.wav', '._A_M01S03.SRC', '._A_F02S48.SRC', 'A_M01S33.SRC', 'A_F02S15.SRC', 'A_M01S29.SRC', '._A_F01S48.SRC', '._A_M02S48.SRC', 'A_F01S21_1.wav', 'A_F01S42.SRC', 'A_F01S51_0.wav', '._A_M02S50.SRC', 'A_M02S48_0.wav', 'A_F01S43_1.wav', 'A_M02S07_1.wav', 'A_M02S29.SRC', '._A_M02S41.SRC', 'A_M02S46.SRC', 'A_M02S43.SRC', 'A_F01S01_0.wav', 'A_F02S16_1.wav', '._A_F02S18.SRC', 'A_M02S21_1.wav', 'A_M02S35_1.wav', '._A_M02S34.SRC', 'A_M01S24_1.wav', 'A_F02S12_0.wav', 'A_M02S16.SRC', 'A_F01S48.SRC', 'A_F02S48_1.wav', 'A_M02S14_1.wav', 'A_M01S37_0.wav', '._A_F02S08.SRC', 'A_F02S15_0.wav', 'A_M02S29_0.wav', 'A_M01S23.SRC', 'A_M01S37_1.wav', 'A_F02S32_1.wav', 'A_M02S02_0.wav', 'A_F01S02.SRC', 'A_M01S03_1.wav', 'A_F02S08_1.wav', '._A_F02S40.SRC', '._A_F02S45.SRC', 'A_F01S11_1.wav', '._A_F01S22.SRC', 'A_F02S05_0.wav', 'A_M01S50_0.wav', '._A_F01S27.SRC', 'A_M02S49_0.wav', '._A_F01S47.SRC', 'A_M01S18_1.wav', 'A_M02S07_0.wav', '._A_F02S34.SRC', 'A_M02S51_1.wav', 'A_M01S38_1.wav', 'A_F02S18_0.wav', '._A_M01S41.SRC', '._A_M01S29.SRC', '._A_M02S14.SRC', 'A_M01S31_1.wav', 'A_M02S45.SRC', 'A_F01S40_0.wav', 'A_F02S13.SRC', '._A_M01S04.SRC', 'A_F01S04.SRC', 'A_M02S37.SRC', 'A_F02S45_1.wav', 'A_M02S46_0.wav', 'A_F01S44.SRC',  ...
# /home/richard/sambashare/media/ITU-T_test/P_Suppl_23_DB/Disk3/EXP3/ORIGINAL/O [] ['._O_F02S79.SRC', 'O_M01S47_1.wav', 'O_M01S73.SRC', 'O_F02S79.SRC', 'O_M01S63_0.wav', 'O_F02S52_1.wav', 'O_F01S75.SRC', 'O_M02S87.SRC', 'O_M02S51.SRC', '._O_M02S47.SRC', 'O_M01S88_1.wav', 'O_F01S84_0.wav', 'O_F02S77_0.wav', 'O_F02S58_0.wav', 'O_F02S92_1.wav', 'O_F02S89_0.wav', 'O_M02S52_1.wav', 'O_M01S52_0.wav', 'O_F01S87.SRC', 'O_F01S85_1.wav', '._O_M02S92.SRC', '._O_M01S96.SRC', 'O_M01S62_0.wav', '._O_M01S62.SRC', '._O_F02S81.SRC', 'O_F02S94_0.wav', 'O_F01S76_1.wav', 'O_F01S76_0.wav', 'O_F02S48.SRC', '._O_M01S71.SRC', 'O_M01S49_0.wav', '._O_F02S66.SRC', 'O_F02S67.SRC', 'O_M01S60.SRC', '._O_F02S55.SRC', 'O_F02S73_1.wav', 'O_F02S69_0.wav', '._O_F02S84.SRC', '._O_F01S88.SRC', 'O_M01S49_1.wav', 'O_M02S82_0.wav', 'O_F01S70_0.wav', 'O_F02S86.SRC', 'O_M02S97.SRC', 'O_M01S72_0.wav', '._O_M02S88.SRC', 'O_F02S49_1.wav', 'O_M02S48.SRC', 'O_M02S89.SRC', 'O_M02S96.SRC', 'O_F02S94_1.wav', 'O_M01S81_0.wav', 'O_F02S71_0.wav', 'O_F01S60_1.wav', 'O_M02S84_0.wav', '._O_M02S49.SRC', '._O_F01S66.SRC', 'O_F01S76.SRC', '._O_F02S78.SRC', 'O_F02S55_1.wav', 'O_M02S94_1.wav', 'O_F02S86_1.wav', 'O_F01S87_0.wav', 'O_F02S51_1.wav', '._O_F02S52.SRC', '._O_F02S62.SRC', 'O_F01S62_1.wav', '._O_F01S62.SRC', 'O_M02S76_0.wav', 'O_F01S63.SRC', '._O_M02S71.SRC', 'O_F02S75_1.wav', 'O_M01S86_1.wav', 'O_F01S54_1.wav', '._O_F02S60.SRC', 'O_F01S70_1.wav', 'O_M02S60_0.wav', 'O_M02S85.SRC', 'O_M02S79_1.wav', 'O_M02S86_0.wav', 'O_M02S47_1.wav', 'O_M02S58.SRC', 'O_M01S89.SRC', '._O_F02S67.SRC', 'O_M02S95_1.wav', 'O_M02S96_1.wav', 'O_F01S62_0.wav', 'O_F01S83.SRC', 'O_M02S68.SRC', 'O_F02S80.SRC', 'O_M02S95_0.wav', '._O_M02S55.SRC', '._O_M01S72.SRC', 'O_M01S62_1.wav', 'O_F01S72_1.wav', 'O_M01S90_0.wav', 'O_M01S95_1.wav', 'O_M01S85_1.wav', 'O_F01S77_1.wav', 'O_F01S87_1.wav', 'O_F02S83_0.wav', 'O_M02S94_0.wav', 'O_M01S54.SRC', '._O_F01S47_0.wav', 'O_F01S83_0.wav', 'O_F02S76.SRC', 'O_F02S88.SRC', 'O_M02S55_1.wav', 'O_M01S62.SRC', 'O_M02S78_1.wav', 'O_F02S66.SRC', 'O_F02S56_1.wav', 'O_F01S63_1.wav', '._O_F02S90.SRC', '._O_F01S98.SRC', '._O_F01S73.SRC', 'O_M01S76.SRC', '._O_M02S79.SRC', '._O_M02S64.SRC', 'O_M01S81.SRC', '._O_M02S91.SRC', 'O_M01S72.SRC', 'O_M01S79.SRC', 'O_M02S74.SRC', '._O_F02S69.SRC', 'O_F02S82.SRC', 'O_M02S61.SRC', 'O_M01S48.SRC', 'O_F01S82.SRC', 'O_F02S87_0.wav', '._O_M01S69.SRC', 'O_F02S71_1.wav', 'O_F01S79_0.wav', '._O_F01S94.SRC', '._O_F01S82.SRC', 'O_M02S78.SRC', 'O_F01S80.SRC', 'O_F01S78.SRC', 'O_F01S95.SRC', 'O_M02S67.SRC', 'O_M02S53_1.wav', 'O_M01S94_1.wav', 'O_M02S49_0.wav', '._O_F01S50.SRC', 'O_M01S69_1.wav', 'O_F01S61_0.wav', '._O_M02S67.SRC', 'O_F01S50_0.wav', '._O_F01S75.SRC', 'O_F02S90_0.wav', 'O_F02S83.SRC', 'O_F02S90.SRC', '._O_F02S82.SRC', '._O_M01S64.SRC', '._O_M01S55.SRC', 'O_M02S61_0.wav', 'O_M02S66_0.wav', 'O_M02S58_1.wav', '._O_F02S50.SRC', 'O_F01S53.SRC', 'O_F01S88_0.wav', 'O_F02S60_1.wav', 'O_M01S56_0.wav', 'O_F01S48_0.wav', 'O_F01S52_0.wav', 'O_M02S60_1.wav', 'O_M02S59_1.wav', 'O_F02S56_0.wav', 'O_F02S77.SRC', 'O_F02S76_0.wav', 'O_F01S48.SRC', '._O_F02S96.SRC', 'O_F01S71.SRC', '._O_F01S92.SRC', 'O_M01S61_0.wav', 'O_F02S54_0.wav', '._O_F02S65.SRC', '._O_M02S53.SRC', 'O_M01S68_0.wav', 'O_F02S86_0.wav', 'O_F02S63_0.wav', 'O_M02S66_1.wav', 'O_F01S72.SRC', 'O_F01S55_0.wav', 'O_F02S96_1.wav', 'O_M02S92_1.wav', 'O_F02S55.SRC', 'O_F01S56_0.wav', '._O_M01S61.SRC', 'O_F01S67_0.wav', '._O_F01S78.SRC', 'O_M01S67_0.wav', '._O_F01S90.SRC', 'O_M01S83.SRC', 'O_F02S50_0.wav', 'O_F01S80_0.wav', 'O_F01S73_1.wav', 'O_F01S71_1.wav', 'O_F02S79_1.wav', '._O_F01S76.SRC', 'O_F02S58_1.wav', '._O_M02S62.SRC', 'O_F02S68.SRC', 'O_F01S61.SRC', 'O_F02S89_1.wav', 'O_M02S54_0.wav', 'O_F01S62.SRC', 'O_M02S82.SRC', 'O_F01S82_1.wav', '._O_M02S48.SRC', '._O_M02S97.SRC', 'O_M01S84.SRC', '._O_F02S95.SRC', 'O_F02S62_0.wav', '._O_F01S49.SRC', 'O_M02S47_0.wav', '._O_M01S63.SRC', 'O_M02S60.SRC', 'O_F01S94_0.wav', 'O_M01S91_1.wav', 'O_M02S80_1.wav', '._O_M01S73.SRC', 'O_F01S57.SRC', 'O_M02S65.SRC',  ...
# Total time: 6966.94

# %%
import subprocess
import re
from scipy.signal import find_peaks

# 'English': O,E
OUT_DATA_DIR = '/home/richard/workspace/test_voice_generation/data/'
playbook = pd.read_csv('/home/richard/workspace/test_voice_generation/metadata/ITU_playlist.csv')
playbook = playbook[(playbook["parent_dir"] == "O") | (playbook["parent_dir"] == "E") ].copy(deep=True).reset_index().sample(frac=1)
display(playbook.iloc[0:10])
pattern = rb"(?<=Gain\[\]:)[^\t]+"

TARGET_LVL = -26
NBITS_MIN = int(20*np.log10(2**(-(NBITS)))) + 1
BIN_WIDTH_CORSE = 3
BINS_CORSE = np.arange(NBITS_MIN, 0, BIN_WIDTH_CORSE)
BIN_WIDTH_FINE = .5
SEARCH_RANGE_BINS = 6
BINS_FINE = np.arange(NBITS_MIN, 0, BIN_WIDTH_FINE)
TOTAL_LENGTH = 10 * FS * 60

y = np.array([])

for i in range(len(playbook)):
    data_path = playbook.iloc[i]["data_path"]
    x,fs = sf.read(data_path)
    vadInst = vad.vad(x, FS, FRAME_DUR, NBITS, NOISE_THR, SMOOTHE_STEP)
    rms = vadInst._ref_rms
    hist, bins_corse = np.histogram(rms, BINS_CORSE)
    peaks_corse, _ = find_peaks(hist, distance=2)
    search_center = bins_corse[peaks_corse[-1]] + BIN_WIDTH_CORSE / 2.0
    
    hist, bins_fine = np.histogram(rms, BINS_FINE)
    peaks_fine, _ = find_peaks(hist, distance=6)
    index = (np.abs(bins_fine - search_center)).argmin()
    # print(bins_fine[index]+BIN_WIDTH_CORSE / 2.0)
    search_range_hist = hist[index-SEARCH_RANGE_BINS:index+SEARCH_RANGE_BINS]
    maxindex = search_range_hist.argmax()
    est_lvl = bins_fine[index - SEARCH_RANGE_BINS + maxindex] + BIN_WIDTH_FINE / 2.0
    gain = 10.0 ** ((TARGET_LVL - est_lvl) / 20.0)
    x = x * gain
    y = np.concatenate([y, x])
    if len(y) >= TOTAL_LENGTH:
        break
sf.write(os.path.join(OUT_DATA_DIR, 'ITU_suppl23.wav'), y, fs, 'PCM_16')    
    
    # # plt.plot(rms)
    # f,ax = plt.subplots(2,1)
    # ax[0].hist(rms, bins=BINS_CORSE, edgecolor='black')
    # ax[1].hist(rms, bins=BINS_FINE, edgecolor='black')
    # break
    # cmd = ['/home/richard/workspace/STL/bin/actlev',  '-q', '-rms', '-lev', '-32', data_path]
    # result = subprocess.run(cmd, stdout=subprocess.PIPE)
    # print(result.stdout)
    # match = re.search(pattern, result.stdout)
    # gain = (float(match.group().decode('utf-8')))
# Out:
#      index     file_id                                          data_path  \
# 820   2977  O_M01S74_0  /home/richard/sambashare/media/ITU-T_test/P_Su...
# 41     101  E_F01S05_0  /home/richard/sambashare/media/ITU-T_test/P_Su...
# 97     980  O_M02S20_1  /home/richard/sambashare/media/ITU-T_test/P_Su...
# 199   1082  O_M01S42_0  /home/richard/sambashare/media/ITU-T_test/P_Su...
# 302   1185  O_M02S27_0  /home/richard/sambashare/media/ITU-T_test/P_Su...
# 35      95  E_F01S06_0  /home/richard/sambashare/media/ITU-T_test/P_Su...
# 434   2591  O_F02S48_0  /home/richard/sambashare/media/ITU-T_test/P_Su...
# 800   2957  O_M02S79_0  /home/richard/sambashare/media/ITU-T_test/P_Su...
# 429   2586  O_F01S75_1  /home/richard/sambashare/media/ITU-T_test/P_Su...
# 381   1264  O_F02S39_0  /home/richard/sambashare/media/ITU-T_test/P_Su...
#
#                                          src_data_path data_set parent_dir  \
# 820  /home/richard/sambashare/media/ITU-T_test/P_Su...  Supp-23          O
# 41   /home/richard/sambashare/media/ITU-T_test/P_Su...  Supp-23          E
# 97   /home/richard/sambashare/media/ITU-T_test/P_Su...  Supp-23          O
# 199  /home/richard/sambashare/media/ITU-T_test/P_Su...  Supp-23          O
# 302  /home/richard/sambashare/media/ITU-T_test/P_Su...  Supp-23          O
# 35   /home/richard/sambashare/media/ITU-T_test/P_Su...  Supp-23          E
# 434  /home/richard/sambashare/media/ITU-T_test/P_Su...  Supp-23          O
# 800  /home/richard/sambashare/media/ITU-T_test/P_Su...  Supp-23          O
# 429  /home/richard/sambashare/media/ITU-T_test/P_Su...  Supp-23          O
# 381  /home/richard/sambashare/media/ITU-T_test/P_Su...  Supp-23          O
#
#        start     stop
# 820  16000.0  58304.0
# 41   16000.0  59712.0
# 97   16000.0  56992.0
# 199  16000.0  60896.0
# 302  16000.0  69216.0
# 35   16000.0  54336.0
# 434  16000.0  63392.0
# 800  16000.0  56576.0
# 429  16000.0  47552.0
# 381  16000.0  50912.0

# %%
bins[peaks[-1]]
# Out:
# -29
